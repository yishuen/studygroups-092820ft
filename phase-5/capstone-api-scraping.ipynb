# %% [markdown]
# # Capstone Recap: APIs and Webscraping
#
# 1. Twint for tweets: https://pypi.org/project/twint/
# 2. Spotipy for Spotify data: https://spotipy.readthedocs.io/en/2.16.1/
# 3. Scraping XML from BoardGameGeek
# 4. Scraping apartments from Craigslist

# %% [markdown]
# ## Twint

# %%
import twint
import pandas as pd

import nest_asyncio # for some reason, needed to excute the api call
nest_asyncio.apply()

# %%
c = twint.Config()
c.Search = "covid"
c.Min_likes = 100
c.Count = True
c.Limit = 100
c.Store_csv = True
c.Output = 'covidtweets.csv'

# %%
twint.run.Search(c)
# Out:
# 1357042101897297921 2021-02-03 14:03:44 -0500 <AP> AstraZeneca’s COVID-19 vaccine appears to reduce transmission of the virus and offer strong protection for three months on just a single dose, researchers say. The preliminary findings appears to be good news in the effort to curb the spread of the virus.  https://t.co/01zRYbTEUc
# 1357041513885282317 2021-02-03 14:01:24 -0500 <KloppStyle> @LFC Please don’t be covid please don’t be covid please don’t be covid please don’t be covid please don’t be covid please don’t be covid please don’t be covid please don’t be covid please don’t be covid please don’t be covid please don’t be covid please don’t be covid
# 1357041455487942658 2021-02-03 14:01:10 -0500 <tumbaburross> Siempre hemos tenido deficiencias en nuestro sistema de salud, pero lo de hoy es inhumano.  Están dejando morir a la gente DE TODO, no solamente de Covid.  ¡Algún día los haremos pagar por tanto daño desgraciados!
# 1357041235752607745 2021-02-03 14:00:17 -0500 <HaddadDebochado> Levantamento da Associação Médica Brasileira (AMB) aponta que mais de 1/3 dos médicos ainda ACREDITAM NO TRATAMENTO PRECOCE, mesmo sendo CIENTIFICAMENTE INEFICAZ contra covid-19.  A pandemia mostrou a quantidade de médico burro e filho da puta que estão cuidando da nossa saúde.
# 1357041063593181188 2021-02-03 13:59:36 -0500 <GovRonDeSantis> I’m pleased to announce 19 Publix Pharmacies in Pasco County, 42 in Pinellas County and 2 in Nassau County will begin offering the COVID-19 vaccine. This brings Florida's partnership with Publix to 325 pharmacies across 23 counties.
# 1357040935151038468 2021-02-03 13:59:06 -0500 <RepValDemings> Today we will vote to sweep aside the bureaucratic blockades that are standing in the way of immediate COVID relief for the American people.  Inaction means suffering for millions of Americans. We want our Republican colleagues to join us—but we won't wait.
# 1357040406412873728 2021-02-03 13:57:00 -0500 <SigaGazetaBR> Brasil tem 8.160.929 milhões de pessoas recuperadas da Covid-19   https://t.co/RVRQC1Wnkw
# 1357039665845465089 2021-02-03 13:54:03 -0500 <esportv> Six Invitational 2021 é suspenso por conta da pandemia de Covid-19  https://t.co/KJYknegJQf  https://t.co/ECTqboZPBA
# 1357038660881952769 2021-02-03 13:50:03 -0500 <CNNPolitics> President Biden tells House Democrats to "stick together" in the Covid-19 relief bill push, signals willingness to narrow stimulus checks  https://t.co/cAHibSJkI4  https://t.co/KPwZuZI6f6
# 1357038443025547264 2021-02-03 13:49:12 -0500 <_makavelijones> Festa da vitória de Lira   Covid?  Pandemia?  Hospitais lotados?   Isso é no Brasil. Não onde esse povo vive, no Brazil.  https://t.co/UUsClUKqlz
# 1357037530282004481 2021-02-03 13:45:34 -0500 <jennfranconews> Sen. Mitch McConnell on COVID relief:  "The new president talks a lot about unity, but his White House staff and congressional leadership are working with a different playbook … the rushed budget process that will play out this week is exactly the wrong path toward making law."
# 1357021029110054915 2021-02-03 12:40:00 -0500 <Estadao> &gt;@EstadaoPolitica Senador Randolfe Rodrigues diz já ter assinaturas para criar CPI da covid-19  https://t.co/Vd3jxNyXbq
# [+] Finished: Successfully collected 100 Tweets.

# %%
tweets = pd.read_csv('covidtweets.csv')

# %%
tweets['tweet']
# Out:
# 0      Importante! Anvisa modifica os requisitos míni...
# 1      Join the CDC #COVID19 Partner Update Call Mond...
# 2      Trying to get things done but can’t stop think...
# 3      Rogan's wildly inconsistent responses to the C...
# 4      Unbelievable: Instead of paying essential work...
#                              ...
# 195    Chris Whitty on Covid deniers:  “If you don’t ...
# 196    A la derecha, un mexicano con necesidad extrem...
# 197    Based on my own experiencing caring for patien...
# 198    Pareciera que la secretaria se manifiesta en c...
# 199    &gt;@EstadaoPolitica Senador Randolfe Rodrigue...
# Name: tweet, Length: 200, dtype: object

# %% [markdown]
# ## Spotipy
# * Documentation: https://spotipy.readthedocs.io/en/2.16.1/
# * Spotify's API: https://developer.spotify.com/dashboard/applications
# * Additional Spotify datasets: https://research.atspotify.com/datasets/
#
# Don't forget to store your credentials!!

# %%
import config
import sys
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(config.client_id, config.client_secret))

# %%
my_user_id = config.user

# %%
playlists = sp.user_playlists(my_user_id)['items']
playlist_ids = [p['id'] for p in playlists]
sp.playlist_tracks(playlist_ids[0])['items']
# Out:
# [{'added_at': '2021-01-15T14:26:44Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gIRvgZssIb9aiirIg0nI3'},
#       'href': 'https://api.spotify.com/v1/artists/3gIRvgZssIb9aiirIg0nI3',
#       'id': '3gIRvgZssIb9aiirIg0nI3',
#       'name': 'Jeremy Zucker',
#       'type': 'artist',
#       'uri': 'spotify:artist:3gIRvgZssIb9aiirIg0nI3'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JMLG56F1X5mFmWNmS0iAp'},
#       'href': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp',
#       'id': '5JMLG56F1X5mFmWNmS0iAp',
#       'name': 'Chelsea Cutler',
#       'type': 'artist',
#       'uri': 'spotify:artist:5JMLG56F1X5mFmWNmS0iAp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5nAv0lNEyaR9IC0RR2UQiW'},
#     'href': 'https://api.spotify.com/v1/albums/5nAv0lNEyaR9IC0RR2UQiW',
#     'id': '5nAv0lNEyaR9IC0RR2UQiW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dccb079c492cf99e02e3255b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dccb079c492cf99e02e3255b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dccb079c492cf99e02e3255b',
#       'width': 64}],
#     'name': 'this is how you fall in love',
#     'release_date': '2021-01-15',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5nAv0lNEyaR9IC0RR2UQiW'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gIRvgZssIb9aiirIg0nI3'},
#      'href': 'https://api.spotify.com/v1/artists/3gIRvgZssIb9aiirIg0nI3',
#      'id': '3gIRvgZssIb9aiirIg0nI3',
#      'name': 'Jeremy Zucker',
#      'type': 'artist',
#      'uri': 'spotify:artist:3gIRvgZssIb9aiirIg0nI3'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5JMLG56F1X5mFmWNmS0iAp'},
#      'href': 'https://api.spotify.com/v1/artists/5JMLG56F1X5mFmWNmS0iAp',
#      'id': '5JMLG56F1X5mFmWNmS0iAp',
#      'name': 'Chelsea Cutler',
#      'type': 'artist',
#      'uri': 'spotify:artist:5JMLG56F1X5mFmWNmS0iAp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 174586,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM72024519'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0742PcMPo2Akmo4vHC29VZ'},
#    'href': 'https://api.spotify.com/v1/tracks/0742PcMPo2Akmo4vHC29VZ',
#    'id': '0742PcMPo2Akmo4vHC29VZ',
#    'is_local': False,
#    'name': 'this is how you fall in love',
#    'popularity': 76,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0742PcMPo2Akmo4vHC29VZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 174167,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1669723'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2My7DsxhZodhsguIHCqAGm'},
#    'href': 'https://api.spotify.com/v1/tracks/2My7DsxhZodhsguIHCqAGm',
#    'id': '2My7DsxhZodhsguIHCqAGm',
#    'is_local': False,
#    'name': "Wouldn't Mean A Thing",
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5726b3f5463edaa350b303c71aa78e6020ab97bd?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2My7DsxhZodhsguIHCqAGm'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 214621,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1671596'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7Jpbi0eEG3WGUhScLt5BgA'},
#    'href': 'https://api.spotify.com/v1/tracks/7Jpbi0eEG3WGUhScLt5BgA',
#    'id': '7Jpbi0eEG3WGUhScLt5BgA',
#    'is_local': False,
#    'name': "There's Little Left",
#    'popularity': 44,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3100dc901cc4ba0d8f925705639c2c684f711418?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7Jpbi0eEG3WGUhScLt5BgA'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 231732,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1673353'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5jcZFcrp4Tmv3x5GkmZL88'},
#    'href': 'https://api.spotify.com/v1/tracks/5jcZFcrp4Tmv3x5GkmZL88',
#    'id': '5jcZFcrp4Tmv3x5GkmZL88',
#    'is_local': False,
#    'name': 'The First Thing You See',
#    'popularity': 43,
#    'preview_url': 'https://p.scdn.co/mp3-preview/44ca1d67ccbe344de21ba3713a60581b1b56f263?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:5jcZFcrp4Tmv3x5GkmZL88'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 210240,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1674673'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2k9N4caeCIJLOWwWwssrEM'},
#    'href': 'https://api.spotify.com/v1/tracks/2k9N4caeCIJLOWwWwssrEM',
#    'id': '2k9N4caeCIJLOWwWwssrEM',
#    'is_local': False,
#    'name': 'Easily',
#    'popularity': 74,
#    'preview_url': 'https://p.scdn.co/mp3-preview/553a07ba23de181462a42649a917f6a7f21b1ae9?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2k9N4caeCIJLOWwWwssrEM'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 200620,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1675818'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4OsBjrJQbPSMAqdjLBaGOt'},
#    'href': 'https://api.spotify.com/v1/tracks/4OsBjrJQbPSMAqdjLBaGOt',
#    'id': '4OsBjrJQbPSMAqdjLBaGOt',
#    'is_local': False,
#    'name': 'Home',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e19551e857d927a458b3cecdc6c59cc858bf6b6a?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4OsBjrJQbPSMAqdjLBaGOt'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 143888,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1777139'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0PwaDQfnz4J8WF8221gv7n'},
#    'href': 'https://api.spotify.com/v1/tracks/0PwaDQfnz4J8WF8221gv7n',
#    'id': '0PwaDQfnz4J8WF8221gv7n',
#    'is_local': False,
#    'name': 'Like Someone In Love',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7016fdfdd01db178a09032fdd967a474934c9e69?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0PwaDQfnz4J8WF8221gv7n'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 205029,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1778049'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5hmjpbBTy8TxV9wDKifSub'},
#    'href': 'https://api.spotify.com/v1/tracks/5hmjpbBTy8TxV9wDKifSub',
#    'id': '5hmjpbBTy8TxV9wDKifSub',
#    'is_local': False,
#    'name': 'Just The Same',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b170502fc478fcc4a27214ac3ffaecb439d863db?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:5hmjpbBTy8TxV9wDKifSub'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 155616,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1779597'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Ub9ro6DKs0u0J0zIBw5Of'},
#    'href': 'https://api.spotify.com/v1/tracks/6Ub9ro6DKs0u0J0zIBw5Of',
#    'id': '6Ub9ro6DKs0u0J0zIBw5Of',
#    'is_local': False,
#    'name': 'Second Time',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/038c97ee7857383bb0937b1fe8a42eb9669d8949?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:6Ub9ro6DKs0u0J0zIBw5Of'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 186712,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1781446'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1I9GllIh1R3EMvTFT5Tfn7'},
#    'href': 'https://api.spotify.com/v1/tracks/1I9GllIh1R3EMvTFT5Tfn7',
#    'id': '1I9GllIh1R3EMvTFT5Tfn7',
#    'is_local': False,
#    'name': 'Fair-Weather Friend',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a92935513be122ed2e8367e844a2d02a92f1844c?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:1I9GllIh1R3EMvTFT5Tfn7'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5UFBJXQtytWA9vfaO2DxLx'},
#     'href': 'https://api.spotify.com/v1/albums/5UFBJXQtytWA9vfaO2DxLx',
#     'id': '5UFBJXQtytWA9vfaO2DxLx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6dfaed2104e0512b7f22256',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6dfaed2104e0512b7f22256',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6dfaed2104e0512b7f22256',
#       'width': 64}],
#     'name': 'A Song For Every Moon',
#     'release_date': '2017-08-31',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5UFBJXQtytWA9vfaO2DxLx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
# ...
#     'href': 'https://api.spotify.com/v1/albums/5ON0EY1YuVEJPwj17yYtwO',
#     'id': '5ON0EY1YuVEJPwj17yYtwO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395998c6ca2c759356eee3c3b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295998c6ca2c759356eee3c3b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195998c6ca2c759356eee3c3b',
#       'width': 64}],
#     'name': 'To Let A Good Thing Die',
#     'release_date': '2020-06-05',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5ON0EY1YuVEJPwj17yYtwO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 195562,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL1973947'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/63BVgRtQ4tWqz83bjl360U'},
#    'href': 'https://api.spotify.com/v1/tracks/63BVgRtQ4tWqz83bjl360U',
#    'id': '63BVgRtQ4tWqz83bjl360U',
#    'is_local': False,
#    'name': 'Tapestry',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d56ef54b6fbcdfbfd361805c586520df4442dda2?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:63BVgRtQ4tWqz83bjl360U'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ON0EY1YuVEJPwj17yYtwO'},
#     'href': 'https://api.spotify.com/v1/albums/5ON0EY1YuVEJPwj17yYtwO',
#     'id': '5ON0EY1YuVEJPwj17yYtwO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395998c6ca2c759356eee3c3b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295998c6ca2c759356eee3c3b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195998c6ca2c759356eee3c3b',
#       'width': 64}],
#     'name': 'To Let A Good Thing Die',
#     'release_date': '2020-06-05',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5ON0EY1YuVEJPwj17yYtwO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 220546,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL2090018'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1siqwUNydX8aQjUIVvJ6Pz'},
#    'href': 'https://api.spotify.com/v1/tracks/1siqwUNydX8aQjUIVvJ6Pz',
#    'id': '1siqwUNydX8aQjUIVvJ6Pz',
#    'is_local': False,
#    'name': "I'll Sleep When I'm Older",
#    'popularity': 50,
#    'preview_url': 'https://p.scdn.co/mp3-preview/36df67dcdc54570bbdda4ae87179cc7e5f43b8e1?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:1siqwUNydX8aQjUIVvJ6Pz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-15T14:27:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#       'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#       'id': '0hDjKSKjl1DC7ovYTDJHe8',
#       'name': 'Bruno Major',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ON0EY1YuVEJPwj17yYtwO'},
#     'href': 'https://api.spotify.com/v1/albums/5ON0EY1YuVEJPwj17yYtwO',
#     'id': '5ON0EY1YuVEJPwj17yYtwO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27395998c6ca2c759356eee3c3b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0295998c6ca2c759356eee3c3b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485195998c6ca2c759356eee3c3b',
#       'width': 64}],
#     'name': 'To Let A Good Thing Die',
#     'release_date': '2020-06-05',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5ON0EY1YuVEJPwj17yYtwO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hDjKSKjl1DC7ovYTDJHe8'},
#      'href': 'https://api.spotify.com/v1/artists/0hDjKSKjl1DC7ovYTDJHe8',
#      'id': '0hDjKSKjl1DC7ovYTDJHe8',
#      'name': 'Bruno Major',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hDjKSKjl1DC7ovYTDJHe8'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 135013,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBKPL2090020'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0lrUh5vot66Srp1aeLTvej'},
#    'href': 'https://api.spotify.com/v1/tracks/0lrUh5vot66Srp1aeLTvej',
#    'id': '0lrUh5vot66Srp1aeLTvej',
#    'is_local': False,
#    'name': 'To Let A Good Thing Die',
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2260a4009adb8956be1b0a7a07d40abce17dad0d?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:0lrUh5vot66Srp1aeLTvej'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-01-23T23:41:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/125382293'},
#    'href': 'https://api.spotify.com/v1/users/125382293',
#    'id': '125382293',
#    'type': 'user',
#    'uri': 'spotify:user:125382293'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kXDB5aeESWj5BD9TCLkMu'},
#       'href': 'https://api.spotify.com/v1/artists/0kXDB5aeESWj5BD9TCLkMu',
#       'id': '0kXDB5aeESWj5BD9TCLkMu',
#       'name': 'Alextbh',
#       'type': 'artist',
#       'uri': 'spotify:artist:0kXDB5aeESWj5BD9TCLkMu'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6zIwkPEI6mOTeSziwCb7zz'},
#     'href': 'https://api.spotify.com/v1/albums/6zIwkPEI6mOTeSziwCb7zz',
#     'id': '6zIwkPEI6mOTeSziwCb7zz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730cc7fbe25c14d04babf875cf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020cc7fbe25c14d04babf875cf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510cc7fbe25c14d04babf875cf',
#       'width': 64}],
#     'name': 'Stoop So Low',
#     'release_date': '2016-11-07',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6zIwkPEI6mOTeSziwCb7zz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0kXDB5aeESWj5BD9TCLkMu'},
#      'href': 'https://api.spotify.com/v1/artists/0kXDB5aeESWj5BD9TCLkMu',
#      'id': '0kXDB5aeESWj5BD9TCLkMu',
#      'name': 'Alextbh',
#      'type': 'artist',
#      'uri': 'spotify:artist:0kXDB5aeESWj5BD9TCLkMu'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'disc_number': 1,
#    'duration_ms': 197938,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'QZ4JJ1607211'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3DNsBFRbQWxygrn4UsqvTF'},
#    'href': 'https://api.spotify.com/v1/tracks/3DNsBFRbQWxygrn4UsqvTF',
#    'id': '3DNsBFRbQWxygrn4UsqvTF',
#    'is_local': False,
#    'name': 'Stoop So Low',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/37af7f4cca438bf1ac77cdad1915d38888d3e758?cid=067be8eb6bf64533866bf9afd450bb11',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3DNsBFRbQWxygrn4UsqvTF'},
#   'video_thumbnail': {'url': None}}]

# %%
def spotipy_search(artist, track):
    query = f'artist: {artist} track: {track}'
    return sp.search(q=query, limit=3)['tracks']['items']

# %%
spotipy_search('dua lipa', 'levitating')
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#      'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#      'id': '4r63FhuTkUYltbVAg5TQnk',
#      'name': 'DaBaby',
#      'type': 'artist',
#      'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/04m06KhJUuwe1Q487puIud'},
#    'href': 'https://api.spotify.com/v1/albums/04m06KhJUuwe1Q487puIud',
#    'id': '04m06KhJUuwe1Q487puIud',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27349caa4fc6f962057ba65576a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0249caa4fc6f962057ba65576a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485149caa4fc6f962057ba65576a',
#      'width': 64}],
#    'name': 'Levitating (feat. DaBaby)',
#    'release_date': '2020-10-01',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:04m06KhJUuwe1Q487puIud'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#     'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#     'id': '6M2wZ9GZgrQXHCFfjv46we',
#     'name': 'Dua Lipa',
#     'type': 'artist',
#     'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#     'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#     'id': '4r63FhuTkUYltbVAg5TQnk',
#     'name': 'DaBaby',
#     'type': 'artist',
#     'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 203064,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHT2000942'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/463CkQjx2Zk1yXoBuierM9'},
#   'href': 'https://api.spotify.com/v1/tracks/463CkQjx2Zk1yXoBuierM9',
#   'id': '463CkQjx2Zk1yXoBuierM9',
#   'is_local': False,
#   'name': 'Levitating (feat. DaBaby)',
#   'popularity': 89,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cc617f669fd1e3ee33a4ac0c66346fefd15286e7?cid=067be8eb6bf64533866bf9afd450bb11',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:463CkQjx2Zk1yXoBuierM9'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5lKlFlReHOLShQKyRv6AL9'},
#    'href': 'https://api.spotify.com/v1/albums/5lKlFlReHOLShQKyRv6AL9',
#    'id': '5lKlFlReHOLShQKyRv6AL9',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ba1fe13f70fffa7430cb3cd1',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ba1fe13f70fffa7430cb3cd1',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ba1fe13f70fffa7430cb3cd1',
#      'width': 64}],
#    'name': 'Future Nostalgia',
#    'release_date': '2020-03-27',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:5lKlFlReHOLShQKyRv6AL9'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#     'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#     'id': '6M2wZ9GZgrQXHCFfjv46we',
#     'name': 'Dua Lipa',
#     'type': 'artist',
#     'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#     'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#     'id': '4r63FhuTkUYltbVAg5TQnk',
#     'name': 'DaBaby',
#     'type': 'artist',
#     'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 203064,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHT2000942'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5nujrmhLynf4yMoMtj8AQF'},
#   'href': 'https://api.spotify.com/v1/tracks/5nujrmhLynf4yMoMtj8AQF',
#   'id': '5nujrmhLynf4yMoMtj8AQF',
#   'is_local': False,
#   'name': 'Levitating (feat. DaBaby)',
#   'popularity': 84,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cc617f669fd1e3ee33a4ac0c66346fefd15286e7?cid=067be8eb6bf64533866bf9afd450bb11',
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:5nujrmhLynf4yMoMtj8AQF'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7fJJK56U9fHixgO0HQkhtI'},
#    'href': 'https://api.spotify.com/v1/albums/7fJJK56U9fHixgO0HQkhtI',
#    'id': '7fJJK56U9fHixgO0HQkhtI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273cda2c6ad6272aea9c5811a49',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02cda2c6ad6272aea9c5811a49',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851cda2c6ad6272aea9c5811a49',
#      'width': 64}],
#    'name': 'Future Nostalgia',
#    'release_date': '2020-03-27',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:7fJJK56U9fHixgO0HQkhtI'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#     'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#     'id': '6M2wZ9GZgrQXHCFfjv46we',
#     'name': 'Dua Lipa',
#     'type': 'artist',
#     'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 203807,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHT1901299'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/39LLxExYz6ewLAcYrzQQyP'},
#   'href': 'https://api.spotify.com/v1/tracks/39LLxExYz6ewLAcYrzQQyP',
#   'id': '39LLxExYz6ewLAcYrzQQyP',
#   'is_local': False,
#   'name': 'Levitating',
#   'popularity': 78,
#   'preview_url': 'https://p.scdn.co/mp3-preview/15e65d052d726b0b7dd4bbff82a02a0537e3995b?cid=067be8eb6bf64533866bf9afd450bb11',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:39LLxExYz6ewLAcYrzQQyP'}]

# %%
sp.search(q='genre: pop', limit=10)['tracks']['items']
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#      'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#      'id': '1McMsnEElThX1knmY4oliG',
#      'name': 'Olivia Rodrigo',
#      'type': 'artist',
#      'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/66FPnVL9G4CMKy3wvaGTcr'},
#    'href': 'https://api.spotify.com/v1/albums/66FPnVL9G4CMKy3wvaGTcr',
#    'id': '66FPnVL9G4CMKy3wvaGTcr',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27359779689e1d9c15ca2f76b84',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0259779689e1d9c15ca2f76b84',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485159779689e1d9c15ca2f76b84',
#      'width': 64}],
#    'name': 'drivers license',
#    'release_date': '2021-01-08',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:66FPnVL9G4CMKy3wvaGTcr'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1McMsnEElThX1knmY4oliG'},
#     'href': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG',
#     'id': '1McMsnEElThX1knmY4oliG',
#     'name': 'Olivia Rodrigo',
#     'type': 'artist',
#     'uri': 'spotify:artist:1McMsnEElThX1knmY4oliG'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 242013,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12004749'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7lPN2DXiMsVn7XUKtOW1CS'},
#   'href': 'https://api.spotify.com/v1/tracks/7lPN2DXiMsVn7XUKtOW1CS',
#   'id': '7lPN2DXiMsVn7XUKtOW1CS',
#   'is_local': False,
#   'name': 'drivers license',
#   'popularity': 100,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:7lPN2DXiMsVn7XUKtOW1CS'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#      'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#      'id': '7tYKF4w9nC0nq9CsPZTHyP',
#      'name': 'SZA',
#      'type': 'artist',
#      'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/781cKhbTPwLnPmo9BALQl7'},
#    'href': 'https://api.spotify.com/v1/albums/781cKhbTPwLnPmo9BALQl7',
#    'id': '781cKhbTPwLnPmo9BALQl7',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733097b1375ab17ae5bf302a0a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023097b1375ab17ae5bf302a0a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048513097b1375ab17ae5bf302a0a',
#      'width': 64}],
#    'name': 'Good Days',
#    'release_date': '2020-12-25',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:781cKhbTPwLnPmo9BALQl7'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7tYKF4w9nC0nq9CsPZTHyP'},
#     'href': 'https://api.spotify.com/v1/artists/7tYKF4w9nC0nq9CsPZTHyP',
#     'id': '7tYKF4w9nC0nq9CsPZTHyP',
#     'name': 'SZA',
#     'type': 'artist',
#     'uri': 'spotify:artist:7tYKF4w9nC0nq9CsPZTHyP'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 279204,
#   'explicit': True,
#   'external_ids': {'isrc': 'USRC12004189'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3YJJjQPAbDT7mGpX3WtQ9A'},
#   'href': 'https://api.spotify.com/v1/tracks/3YJJjQPAbDT7mGpX3WtQ9A',
#   'id': '3YJJjQPAbDT7mGpX3WtQ9A',
#   'is_local': False,
#   'name': 'Good Days',
#   'popularity': 92,
#   'preview_url': 'https://p.scdn.co/mp3-preview/297942feb416d50b8ee69f760daf1e2a1f39dabc?cid=067be8eb6bf64533866bf9afd450bb11',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3YJJjQPAbDT7mGpX3WtQ9A'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3euz4vS7ezKGnNSwgyvKcd'},
#    'href': 'https://api.spotify.com/v1/albums/3euz4vS7ezKGnNSwgyvKcd',
#    'id': '3euz4vS7ezKGnNSwgyvKcd',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735ef878a782c987d38d82b605',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025ef878a782c987d38d82b605',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515ef878a782c987d38d82b605',
#      'width': 64}],
#    'name': 'Positions',
#    'release_date': '2020-10-30',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:3euz4vS7ezKGnNSwgyvKcd'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#     'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#     'id': '66CXWjxzNUsdJxJ2JdwvnR',
#     'name': 'Ariana Grande',
#     'type': 'artist',
#     'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 172324,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM72019412'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/35mvY5S1H3J2QZyna3TFe0'},
#   'href': 'https://api.spotify.com/v1/tracks/35mvY5S1H3J2QZyna3TFe0',
#   'id': '35mvY5S1H3J2QZyna3TFe0',
#   'is_local': False,
#   'name': 'positions',
#   'popularity': 94,
#   'preview_url': None,
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:35mvY5S1H3J2QZyna3TFe0'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#      'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#      'id': '66CXWjxzNUsdJxJ2JdwvnR',
#      'name': 'Ariana Grande',
#      'type': 'artist',
#      'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3euz4vS7ezKGnNSwgyvKcd'},
#    'href': 'https://api.spotify.com/v1/albums/3euz4vS7ezKGnNSwgyvKcd',
#    'id': '3euz4vS7ezKGnNSwgyvKcd',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735ef878a782c987d38d82b605',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025ef878a782c987d38d82b605',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515ef878a782c987d38d82b605',
#      'width': 64}],
#    'name': 'Positions',
#    'release_date': '2020-10-30',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:3euz4vS7ezKGnNSwgyvKcd'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#     'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#     'id': '66CXWjxzNUsdJxJ2JdwvnR',
#     'name': 'Ariana Grande',
#     'type': 'artist',
#     'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 173710,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUM72020423'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6Im9k8u9iIzKMrmV7BWtlF'},
#   'href': 'https://api.spotify.com/v1/tracks/6Im9k8u9iIzKMrmV7BWtlF',
#   'id': '6Im9k8u9iIzKMrmV7BWtlF',
#   'is_local': False,
#   'name': '34+35',
#   'popularity': 92,
#   'preview_url': None,
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:6Im9k8u9iIzKMrmV7BWtlF'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#    'href': 'https://api.spotify.com/v1/albums/4yP0hdKOZPNshxUOjY0cZj',
#    'id': '4yP0hdKOZPNshxUOjY0cZj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2738863bc11d2aa12b54f5aeb36',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e028863bc11d2aa12b54f5aeb36',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048518863bc11d2aa12b54f5aeb36',
#      'width': 64}],
#    'name': 'After Hours',
#    'release_date': '2020-03-20',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:4yP0hdKOZPNshxUOjY0cZj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#     'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#     'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#     'name': 'The Weeknd',
#     'type': 'artist',
#     'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 200040,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUG11904206'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0VjIjW4GlUZAMYd2vXMi3b'},
#   'href': 'https://api.spotify.com/v1/tracks/0VjIjW4GlUZAMYd2vXMi3b',
#   'id': '0VjIjW4GlUZAMYd2vXMi3b',
#   'is_local': False,
#   'name': 'Blinding Lights',
#   'popularity': 95,
#   'preview_url': None,
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:0VjIjW4GlUZAMYd2vXMi3b'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/51kijm0sjZz0yOa3kVBPUU'},
#    'href': 'https://api.spotify.com/v1/albums/51kijm0sjZz0yOa3kVBPUU',
#    'id': '51kijm0sjZz0yOa3kVBPUU',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2734b02db5cefb177ff97346cf2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e024b02db5cefb177ff97346cf2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048514b02db5cefb177ff97346cf2',
#      'width': 64}],
#    'name': 'Anyone',
#    'release_date': '2021-01-01',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:51kijm0sjZz0yOa3kVBPUU'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#     'id': '1uNFoZAHBGtllmzznpCI3s',
#     'name': 'Justin Bieber',
#     'type': 'artist',
#     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 190779,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72023175'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/31qCy5ZaophVA81wtlwLc4'},
#   'href': 'https://api.spotify.com/v1/tracks/31qCy5ZaophVA81wtlwLc4',
#   'id': '31qCy5ZaophVA81wtlwLc4',
#   'is_local': False,
#   'name': 'Anyone',
#   'popularity': 91,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:31qCy5ZaophVA81wtlwLc4'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#      'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#      'id': '5cj0lLjcoR7YOSnhnX0Po5',
#      'name': 'Doja Cat',
#      'type': 'artist',
#      'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1MmVkhiwTH0BkNOU3nw5d3'},
#    'href': 'https://api.spotify.com/v1/albums/1MmVkhiwTH0BkNOU3nw5d3',
#    'id': '1MmVkhiwTH0BkNOU3nw5d3',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27382b243023b937fd579a35533',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0282b243023b937fd579a35533',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485182b243023b937fd579a35533',
#      'width': 64}],
#    'name': 'Hot Pink',
#    'release_date': '2019-11-07',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:1MmVkhiwTH0BkNOU3nw5d3'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5cj0lLjcoR7YOSnhnX0Po5'},
#     'href': 'https://api.spotify.com/v1/artists/5cj0lLjcoR7YOSnhnX0Po5',
#     'id': '5cj0lLjcoR7YOSnhnX0Po5',
#     'name': 'Doja Cat',
#     'type': 'artist',
#     'uri': 'spotify:artist:5cj0lLjcoR7YOSnhnX0Po5'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 226986,
#   'explicit': True,
#   'external_ids': {'isrc': 'USRC11903460'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/60ynsPSSKe6O3sfwRnIBRf'},
#   'href': 'https://api.spotify.com/v1/tracks/60ynsPSSKe6O3sfwRnIBRf',
#   'id': '60ynsPSSKe6O3sfwRnIBRf',
#   'is_local': False,
#   'name': 'Streets',
#   'popularity': 88,
#   'preview_url': 'https://p.scdn.co/mp3-preview/72699a9f3ab9479740438e33cbbd4af05777329c?cid=067be8eb6bf64533866bf9afd450bb11',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:60ynsPSSKe6O3sfwRnIBRf'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#      'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#      'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#      'name': 'Billie Eilish',
#      'type': 'artist',
#      'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5G58VVE9ub1KE01Mvbd8XM'},
#    'href': 'https://api.spotify.com/v1/albums/5G58VVE9ub1KE01Mvbd8XM',
#    'id': '5G58VVE9ub1KE01Mvbd8XM',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fec5ef9f3133aff71c525acc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fec5ef9f3133aff71c525acc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fec5ef9f3133aff71c525acc',
#      'width': 64}],
#    'name': 'Therefore I Am',
#    'release_date': '2020-11-12',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:5G58VVE9ub1KE01Mvbd8XM'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#     'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#     'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#     'name': 'Billie Eilish',
#     'type': 'artist',
#     'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 174321,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM72021500'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/54bFM56PmE4YLRnqpW6Tha'},
#   'href': 'https://api.spotify.com/v1/tracks/54bFM56PmE4YLRnqpW6Tha',
#   'id': '54bFM56PmE4YLRnqpW6Tha',
#   'is_local': False,
#   'name': 'Therefore I Am',
#   'popularity': 92,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:54bFM56PmE4YLRnqpW6Tha'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#      'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#      'id': '6M2wZ9GZgrQXHCFfjv46we',
#      'name': 'Dua Lipa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#      'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#      'id': '4r63FhuTkUYltbVAg5TQnk',
#      'name': 'DaBaby',
#      'type': 'artist',
#      'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/04m06KhJUuwe1Q487puIud'},
#    'href': 'https://api.spotify.com/v1/albums/04m06KhJUuwe1Q487puIud',
#    'id': '04m06KhJUuwe1Q487puIud',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27349caa4fc6f962057ba65576a',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0249caa4fc6f962057ba65576a',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485149caa4fc6f962057ba65576a',
#      'width': 64}],
#    'name': 'Levitating (feat. DaBaby)',
#    'release_date': '2020-10-01',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:04m06KhJUuwe1Q487puIud'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6M2wZ9GZgrQXHCFfjv46we'},
#     'href': 'https://api.spotify.com/v1/artists/6M2wZ9GZgrQXHCFfjv46we',
#     'id': '6M2wZ9GZgrQXHCFfjv46we',
#     'name': 'Dua Lipa',
#     'type': 'artist',
#     'uri': 'spotify:artist:6M2wZ9GZgrQXHCFfjv46we'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4r63FhuTkUYltbVAg5TQnk'},
#     'href': 'https://api.spotify.com/v1/artists/4r63FhuTkUYltbVAg5TQnk',
#     'id': '4r63FhuTkUYltbVAg5TQnk',
#     'name': 'DaBaby',
#     'type': 'artist',
#     'uri': 'spotify:artist:4r63FhuTkUYltbVAg5TQnk'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 203064,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHT2000942'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/463CkQjx2Zk1yXoBuierM9'},
#   'href': 'https://api.spotify.com/v1/tracks/463CkQjx2Zk1yXoBuierM9',
#   'id': '463CkQjx2Zk1yXoBuierM9',
#   'is_local': False,
#   'name': 'Levitating (feat. DaBaby)',
#   'popularity': 89,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cc617f669fd1e3ee33a4ac0c66346fefd15286e7?cid=067be8eb6bf64533866bf9afd450bb11',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:463CkQjx2Zk1yXoBuierM9'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#      'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#      'id': '3TVXtAsR1Inumwj472S9r4',
#      'name': 'Drake',
#      'type': 'artist',
#      'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#      'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#      'id': '3hcs9uc56yIGFCSy9leWe7',
#      'name': 'Lil Durk',
#      'type': 'artist',
#      'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'}],
#    'available_markets': ['AD',
#     'AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PS',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0qGdc7fNq9RNIPEzZufa43'},
#    'href': 'https://api.spotify.com/v1/albums/0qGdc7fNq9RNIPEzZufa43',
#    'id': '0qGdc7fNq9RNIPEzZufa43',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27352c75ed37313b889447011ef',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0252c75ed37313b889447011ef',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485152c75ed37313b889447011ef',
#      'width': 64}],
#    'name': 'Laugh Now Cry Later (feat. Lil Durk)',
#    'release_date': '2020-08-14',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:0qGdc7fNq9RNIPEzZufa43'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#     'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#     'id': '3TVXtAsR1Inumwj472S9r4',
#     'name': 'Drake',
#     'type': 'artist',
#     'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3hcs9uc56yIGFCSy9leWe7'},
#     'href': 'https://api.spotify.com/v1/artists/3hcs9uc56yIGFCSy9leWe7',
#     'id': '3hcs9uc56yIGFCSy9leWe7',
#     'name': 'Lil Durk',
#     'type': 'artist',
#     'uri': 'spotify:artist:3hcs9uc56yIGFCSy9leWe7'}],
#   'available_markets': ['AD',
#    'AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'BY',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JO',
#    'JP',
#    'KR',
#    'KW',
#    'KZ',
#    'LB',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PS',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 261492,
#   'explicit': True,
#   'external_ids': {'isrc': 'USUG12001748'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2SAqBLGA283SUiwJ3xOUVI'},
#   'href': 'https://api.spotify.com/v1/tracks/2SAqBLGA283SUiwJ3xOUVI',
#   'id': '2SAqBLGA283SUiwJ3xOUVI',
#   'is_local': False,
#   'name': 'Laugh Now Cry Later (feat. Lil Durk)',
#   'popularity': 88,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2SAqBLGA283SUiwJ3xOUVI'}]

# %% [markdown]
# ## Webscraping Boardgames
#
# (And dealing with XML formats)

# %%
import json
import requests
import time
from bs4 import BeautifulSoup

# %%
url = 'https://boardgamegeek.com/xmlapi2/thing?id=3&type=boardgame'
req = requests.get(url).content
soup = BeautifulSoup(req, 'xml')
games = soup.find_all('item')

# %%
games[0]
# Out:
# <item id="3" type="boardgame">
# <thumbnail>https://cf.geekdo-images.com/o9-sNXmFS_TLAb7ZlZ4dRA__thumb/img/22MSUC0-ZWgwzhi_VKIbENJik1w=/fit-in/200x150/filters:strip_icc()/pic3211873.jpg</thumbnail>
# https://cf.geekdo-images.com/o9-sNXmFS_TLAb7ZlZ4dRA__original/img/TPKZgpNxB_C73RNbhKyP6UR76X0=/0x0/filters:format(jpeg)/pic3211873.jpg
# <name sortindex="1" type="primary" value="Samurai"/>
# <name sortindex="1" type="alternate" value="Samouraï"/>
# <name sortindex="1" type="alternate" value="Samurái"/>
# <name sortindex="1" type="alternate" value="Samuraj"/>
# <name sortindex="1" type="alternate" value="Самурай"/>
# <name sortindex="1" type="alternate" value="侍"/>
# <name sortindex="1" type="alternate" value="사무라이"/>
# <description>Samurai is set in medieval Japan. Players compete to gain the favor of three factions: samurai, peasants, and priests, which are represented by helmet, rice paddy, and Buddha figures scattered about the board, which features the islands of Japan. The competition is waged through the use of hexagonal tiles, each of which help curry favor of one of the three factions &amp;mdash; or all three at once! Players can make lightning-quick strikes with horseback ronin and ships or approach their conquests more methodically. As each figure (helmets, rice paddies, and Buddhas) is surrounded, it is awarded to the player who has gained the most favor with the corresponding group.&amp;#10;&amp;#10;Gameplay continues until all the symbols of one type have been removed from the board or four figures have been removed from play due to a tie for influence.&amp;#10;&amp;#10;At the end of the game, players compare captured symbols of each type, competing for majorities in each of the three types. Ties are not uncommon and are broken based on the number of other, &amp;quot;non-majority&amp;quot; symbols each player has collected.&amp;#10;&amp;#10;The game is part of what is sometimes called the Knizia tile-laying trilogy.&amp;#10;&amp;#10;</description>
# <yearpublished value="1998"/>
# <minplayers value="2"/>
# <maxplayers value="4"/>
# <poll name="suggested_numplayers" title="User Suggested Number of Players" totalvotes="310">
# <results numplayers="1">
# <result numvotes="0" value="Best"/>
# <result numvotes="0" value="Recommended"/>
# <result numvotes="147" value="Not Recommended"/>
# </results>
# <results numplayers="2">
# <result numvotes="103" value="Best"/>
# <result numvotes="151" value="Recommended"/>
# <result numvotes="16" value="Not Recommended"/>
# </results>
# <results numplayers="3">
# <result numvotes="178" value="Best"/>
# <result numvotes="92" value="Recommended"/>
# <result numvotes="2" value="Not Recommended"/>
# </results>
# <results numplayers="4">
# <result numvotes="79" value="Best"/>
# <result numvotes="145" value="Recommended"/>
# <result numvotes="27" value="Not Recommended"/>
# </results>
# <results numplayers="4+">
# <result numvotes="0" value="Best"/>
# <result numvotes="1" value="Recommended"/>
# <result numvotes="122" value="Not Recommended"/>
# </results>
# </poll> <playingtime value="60"/>
# <minplaytime value="30"/>
# <maxplaytime value="60"/>
# <minage value="10"/>
# <poll name="suggested_playerage" title="User Suggested Player Age" totalvotes="51">
# <results>
# <result numvotes="0" value="2"/>
# <result numvotes="0" value="3"/>
# <result numvotes="0" value="4"/>
# <result numvotes="0" value="5"/>
# <result numvotes="4" value="6"/>
# <result numvotes="13" value="8"/>
# <result numvotes="29" value="10"/>
# <result numvotes="5" value="12"/>
# <result numvotes="0" value="14"/>
# <result numvotes="0" value="16"/>
# <result numvotes="0" value="18"/>
# <result numvotes="0" value="21 and up"/>
# </results>
# </poll> <poll name="language_dependence" title="Language Dependence" totalvotes="72">
# <results>
# <result level="1" numvotes="72" value="No necessary in-game text"/>
# <result level="2" numvotes="0" value="Some necessary text - easily memorized or small crib sheet"/>
# <result level="3" numvotes="0" value="Moderate in-game text - needs crib sheet or paste ups"/>
# <result level="4" numvotes="0" value="Extensive use of text - massive conversion needed to be playable"/>
# <result level="5" numvotes="0" value="Unplayable in another language"/>
# </results>
# </poll>
# <link id="1009" type="boardgamecategory" value="Abstract Strategy"/>
# <link id="1035" type="boardgamecategory" value="Medieval"/>
# <link id="2080" type="boardgamemechanic" value="Area Majority / Influence"/>
# <link id="2040" type="boardgamemechanic" value="Hand Management"/>
# <link id="2026" type="boardgamemechanic" value="Hexagon Grid"/>
# <link id="2846" type="boardgamemechanic" value="Once-Per-Game Abilities"/>
# <link id="2004" type="boardgamemechanic" value="Set Collection"/>
# <link id="2002" type="boardgamemechanic" value="Tile Placement"/>
# <link id="10634" type="boardgamefamily" value="Country: Japan"/>
# <link id="60111" type="boardgamefamily" value="Series: Euro Classics (Reiner Knizia)"/>
# <link id="42" type="boardgamefamily" value="Series: Tile-Laying Trilogy (Reiner Knizia)"/>
# <link id="28732" type="boardgamefamily" value="Theme: Samurai"/>
# <link id="35634" type="boardgameimplementation" value="Samurai: The Card Game"/>
# <link id="2" type="boardgamedesigner" value="Reiner Knizia"/>
# <link id="11883" type="boardgameartist" value="Franz Vohwinkel"/>
# <link id="17" type="boardgamepublisher" value="Fantasy Flight Games"/>
# <link id="133" type="boardgamepublisher" value="Hans im Glück"/>
# <link id="267" type="boardgamepublisher" value="999 Games"/>
# <link id="29" type="boardgamepublisher" value="ABACUSSPIELE"/>
# <link id="7340" type="boardgamepublisher" value="Astrel Games"/>
# <link id="7335" type="boardgamepublisher" value="Ceilikan Jogos"/>
# <link id="41" type="boardgamepublisher" value="Descartes Editeur"/>
# <link id="2973" type="boardgamepublisher" value="Edge Entertainment"/>
# <link id="4617" type="boardgamepublisher" value="Galakta"/>
# <link id="1391" type="boardgamepublisher" value="Hobby Japan"/>
# <link id="8291" type="boardgamepublisher" value="Korea Boardgames Co., Ltd."/>
# <link id="5812" type="boardgamepublisher" value="Lacerta"/>
# <link id="3218" type="boardgamepublisher" value="Lautapelit.fi"/>
# <link id="3" type="boardgamepublisher" value="Rio Grande Games"/>
# <link id="3954" type="boardgamepublisher" value="Skandinavisk  Spil Kompagni"/>
# <link id="8313" type="boardgamepublisher" value="Smart Ltd"/>
# <link id="8759" type="boardgamepublisher" value="Wargames Club Publishing"/>
# </item>

# %%
names = games[0].find_all('name')
names
# Out:
# [<name sortindex="1" type="primary" value="Samurai"/>,
#  <name sortindex="1" type="alternate" value="Samouraï"/>,
#  <name sortindex="1" type="alternate" value="Samurái"/>,
#  <name sortindex="1" type="alternate" value="Samuraj"/>,
#  <name sortindex="1" type="alternate" value="Самурай"/>,
#  <name sortindex="1" type="alternate" value="侍"/>,
#  <name sortindex="1" type="alternate" value="사무라이"/>]

# %%
games[0].find_all('name')[0]['type']
# Out:
# 'primary'

# %%
name = list(filter(lambda n: n['type'] == "primary", names))

# %%
name[0]['value']
# Out:
# 'Samurai'

# %%
games[0].find('description').text
# Out:
# 'Samurai is set in medieval Japan. Players compete to gain the favor of three factions: samurai, peasants, and priests, which are represented by helmet, rice paddy, and Buddha figures scattered about the board, which features the islands of Japan. The competition is waged through the use of hexagonal tiles, each of which help curry favor of one of the three factions &mdash; or all three at once! Players can make lightning-quick strikes with horseback ronin and ships or approach their conquests more methodically. As each figure (helmets, rice paddies, and Buddhas) is surrounded, it is awarded to the player who has gained the most favor with the corresponding group.&#10;&#10;Gameplay continues until all the symbols of one type have been removed from the board or four figures have been removed from play due to a tie for influence.&#10;&#10;At the end of the game, players compare captured symbols of each type, competing for majorities in each of the three types. Ties are not uncommon and are broken based on the number of other, &quot;non-majority&quot; symbols each player has collected.&#10;&#10;The game is part of what is sometimes called the Knizia tile-laying trilogy.&#10;&#10;'

# %% [markdown]
# ## Scraping Craigslist
#
# https://newyork.craigslist.org/search/aap

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url = 'https://newyork.craigslist.org/search/hhh?'
soup = BeautifulSoup(requests.get(url).text)

# getting each apartment's html as an element in a list

apartments =  soup.findAll('li', {'class':"result-row"})

# %%
apartments[0]
# Out:
# <li class="result-row" data-pid="7272107009" data-repost-of="6998435258">
# <a class="result-image gallery" data-ids="3:00z0z_byG0RkJRpzO_0CI0pO,3:00E0E_cVHFXCBXhxw_0CI0pO,3:01111_h1zE3Bb56Uc_0Ny1ck,3:00u0u_37A9KV9fXmv_0pO0CI,3:00V0V_jBnumoAuceK_0CI0pO,3:00O0O_kJ9lOOrjDJe_0CI0pO,3:00k0k_cP3WBg3LP5W_0CI0pO,3:00q0q_hnY6OeS9ScS_0t20CI,3:00x0x_2I9xDfltOCo_0t20CI,3:00M0M_eDMlMU02g9m_0t20CI,3:00b0b_2F3sfI9LUW_0CI0pO,3:00v0v_lLBdntamwai_0t20CI,3:00O0O_gzRXJZOcTOH_0t20CI,3:00Z0Z_2ba7RSRx3QY_0CI0pO,3:00Y0Y_kTHyu2DtvZ0_0CI0pO" href="https://newyork.craigslist.org/stn/roo/d/staten-island-12-minute-walk-from-ferry/7272107009.html">
# <span class="result-price">$750</span>
# </a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-02-03 14:37" title="Wed 03 Feb 02:37:25 PM">Feb  3</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7272107009" href="https://newyork.craigslist.org/stn/roo/d/staten-island-12-minute-walk-from-ferry/7272107009.html" id="postid_7272107009">12 minute walk from Ferry $750</a>
# </h3>
# <span class="result-meta">
# <span class="result-price">$750</span>
# <span class="housing">
#                     3br -
#                     950ft<sup>2</sup> -
#                 </span>
# <span class="result-hood"> (Staten Island)</span>
# <span class="result-tags">
# <span class="pictag">pic</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </div>
# </li>

# %%
titles = [a.find('a', {'class': 'result-title hdrlnk'}).text for a in apartments]
prices = [a.find('span', {'class': 'result-price'}).text for a in apartments]

# %%
len(prices)
# Out:
# 120

# %%
# getting attributes via list comprehension
hoods = []
for a in apartments:
    result = a.find('span', {'class': 'result-hood'})
    if result == None:
        hoods.append(None)
    else:
        hoods.append(result.text)

# for 'hoods', some are NoneType

# putting it in a dataframe:

df = pd.DataFrame(columns = ['titles', 'prices', 'hoods'])
df['titles'] = titles
df['prices'] = prices
df['hoods'] = hoods

# %%
df
# Out:
#                                                 titles  prices  \
# 0                       12 minute walk from Ferry $750    $750
# 1    NEW CONSTRUCTION | LUXURY CONDO | TWO PRIVATE ...  $1,275
# 2                                  FRESH ON THE MARKET    $700
# 3    PRIVATE OFFICE WITH ITS OWN PRIVATE TOILET & P...  $3,000
# 4               Attorney Offices and Cubicles for Rent      $0
# ..                                                 ...     ...
# 115                    750 with all utilities included    $750
# 116  Large 2 bedroom+Laundry great sunlight+ Patio ...  $2,665
# 117  NO BROKER FEE - MUST SEE! High End 3 BR Apt wi...  $2,800
# 118   4Bed w/ office space PRIME BEDSTUY in Brownstone  $4,200
# 119                                    Amazing Bedroom    $800
#
#                     hoods
# 0         (Staten Island)
# 1              (Bushwick)
# 2         (East Flatbush)
# 3              (Brooklyn)
# 4     (Downtown Brooklyn)
# ..                    ...
# 115       (Staten Island)
# 116       (Bergen street)
# 117            (Brooklyn)
# 118            (Brooklyn)
# 119        (Williamsburg)
#
# [120 rows x 3 columns]

# %% [markdown]
# ## Additional Things to Explore
#
# * BeautifulSoup not finding the exact info you're trying to scrape? Try **Selenium**
#     * https://www.scrapingbee.com/blog/selenium-python/
#
# * ScraPy is another library (newer) used for scraping
#     * https://scrapy.org/
